# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("E:/Netflix/netflix_movies_detailed_up_to_2025.csv")
df = pd.DataFrame(data)
print(df)
# Out:
#        show_id   type                                         title  \
# 0        10192  Movie                           Shrek Forever After
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# ...        ...    ...                                           ...
# 15995  1440286  Movie         Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                                 Man and Woman
# 15997  1426364  Movie              Night of the Dead Sorority Babes
# 15998  1411248  Movie                               A Dunces Burden
# 15999  1405742  Movie                                Portal to Hell
#
#                                     director  \
# 0                              Mike Mitchell
# 1                          Christopher Nolan
# ...

# %%
df.head(10)
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
# 5    11324  Movie                                Shutter Island
# 6    38575  Movie                                The Karate Kid
# 7    10138  Movie                                    Iron Man 2
# 8    38365  Movie                                     Grown Ups
# 9    48650  Movie                                  Room in Rome
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
# 5              Martin Scorsese
# 6                 Harald Zwart
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director          132
# cast              204
# country           466
# date_added          0
# release_year        0
# rating              0
# duration        16000
# genres            107
# language            0
# description       132
# popularity          0
# vote_count          0
# vote_average        0
# budget              0
# revenue             0
# dtype: int64

# %%
print(data["show_id"].duplicated().sum())
# Out:
# 0

# %%
cols = ['duration','cast','language','description','budget','revenue']
df.drop(cols, axis=1, inplace=True)

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11988\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      16000 non-null  object
#  4   country       16000 non-null  object
#  5   date_added    16000 non-null  object
#  6   release_year  16000 non-null  int64
#  7   rating        16000 non-null  float64
#  8   genres        16000 non-null  object
#  9   popularity    16000 non-null  float64
#  10  vote_count    16000 non-null  int64
#  11  vote_average  16000 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 1.5+ MB

# %%
df["genres"].head()
# Out:
# 0    Comedy, Adventure, Fantasy, Animation, Family
# 1               Action, Science Fiction, Adventure
# 2                               Adventure, Fantasy
# 3                     Animation, Family, Adventure
# 4            Fantasy, Adventure, Animation, Family
# Name: genres, dtype: object

# %%
df["release_year"] = pd.to_datetime(df["release_year"])
print(df["release_year"].dtype)
# Out:
# datetime64[ns]

# %%
df['release_year'] = pd.to_datetime(df['release_year']).dt.year
print(df['release_year'].dtype)
# Out:
# int32

# %%
df["date_added"] = pd.to_datetime(df["date_added"])
print(df["date_added"].dtype)
# Out:
# datetime64[ns]

# %%
df["date_added"] = pd.to_datetime(df["date_added"]).dt.year
print(df["date_added"].dtype)
# Out:
# int32

# %%
df.describe()
# Out:
#             show_id  release_year        rating    popularity    vote_count  \
# count  1.600000e+04       16000.0  16000.000000  16000.000000  16000.000000
# mean   5.266582e+05        1970.0      5.956368     20.384728    718.656125
# std    3.794427e+05           0.0      1.754741     68.610033   2080.198316
# min    1.890000e+02        1970.0      0.000000      3.860000      0.000000
# 25%    2.257258e+05        1970.0      5.600000      7.840750     53.000000
# 50%    4.468170e+05        1970.0      6.300000     10.913500    138.000000
# 75%    7.739808e+05        1970.0      6.923000     17.336500    422.000000
# max    1.440471e+06        1970.0     10.000000   3876.006000  37119.000000
#
#        vote_average
# count  16000.000000
# mean       5.956368
# std        1.754741
# min        0.000000
# 25%        5.600000
# 50%        6.300000
# 75%        6.923000
# max       10.000000

# %%
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director                                   country  \
# 0                Mike Mitchell                  United States of America
# 1            Christopher Nolan  United Kingdom, United States of America
# 2                  David Yates  United Kingdom, United States of America
# 3   Byron Howard, Nathan Greno                  United States of America
# 4  Chris Sanders, Dean DeBlois                  United States of America
#
#    date_added  release_year  rating  \
# 0  2010-05-16          1970   6.380
# 1  2010-07-15          1970   8.369
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      16000 non-null  object
#  4   country       16000 non-null  object
#  5   date_added    16000 non-null  datetime64[ns]
#  6   release_year  16000 non-null  int32
#  7   rating        16000 non-null  float64
#  8   genres        16000 non-null  object
#  9   popularity    16000 non-null  float64
#  10  vote_count    16000 non-null  int64
#  11  vote_average  16000 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
print(df['date_added'].dtype)
# Out:
# datetime64[ns]

# %%
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director                                   country  \
# 0                Mike Mitchell                  United States of America
# 1            Christopher Nolan  United Kingdom, United States of America
# 2                  David Yates  United Kingdom, United States of America
# 3   Byron Howard, Nathan Greno                  United States of America
# 4  Chris Sanders, Dean DeBlois                  United States of America
#
#   date_added  release_year  rating  \
# 0 2010-05-16          1970   6.380
# 1 2010-07-15          1970   8.369
# ...

# %% [markdown]
# Cetegories average_vote column
# We would cut the vote_Average values and make 4 categories. popular average below_abg not_popular to describe it more using categories_col() function provide above

# %%
def categorize_col(df,col,labels):
    edges = [df[col].describe()['min'],
             df[col].describe()['25%'],
             df[col].describe()['50%'],
             df[col].describe()['75%'],
             df[col].describe()['max']]
    df[col] = pd.cut(df[col], edges, labels = labels, duplicates = 'drop')
    return df

# %%
labels = ['not_popular', 'below_avg', 'average','popular']

categorize_col(df,'vote_average', labels)

df['vote_average'].unique()
# Out:
# ['average', 'popular', 'below_avg', 'not_popular', NaN]
# Categories (4, object): ['not_popular' < 'below_avg' < 'average' < 'popular']

# %%
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director                                   country  \
# 0                Mike Mitchell                  United States of America
# 1            Christopher Nolan  United Kingdom, United States of America
# 2                  David Yates  United Kingdom, United States of America
# 3   Byron Howard, Nathan Greno                  United States of America
# 4  Chris Sanders, Dean DeBlois                  United States of America
#
#   date_added  release_year  rating  \
# 0 2010-05-16          1970   6.380
# 1 2010-07-15          1970   8.369
# ...

# %%
df['vote_average'].value_counts()
# Out:
# vote_average
# below_avg      4024
# popular        3999
# average        3785
# not_popular    3293
# Name: count, dtype: int64

# %%
df.dropna(inplace = True)
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# genres          0
# popularity      0
# vote_count      0
# vote_average    0
# dtype: int64

# %% [markdown]
# #### we'd split genres into a list and then explode our dataframe to have only one genre per row for each movie

# %%
df['genres'].head()
# Out:
# 0    Comedy, Adventure, Fantasy, Animation, Family
# 1               Action, Science Fiction, Adventure
# 2                               Adventure, Fantasy
# 3                     Animation, Family, Adventure
# 4            Fantasy, Adventure, Animation, Family
# Name: genres, dtype: object

# %%
df['genres'] = df['genres'].str.split(', ')
df = df.explode('genres').reset_index(drop = True)
df.head()
# Out:
#    show_id   type                title       director  \
# 0    10192  Movie  Shrek Forever After  Mike Mitchell
# 1    10192  Movie  Shrek Forever After  Mike Mitchell
# 2    10192  Movie  Shrek Forever After  Mike Mitchell
# 3    10192  Movie  Shrek Forever After  Mike Mitchell
# 4    10192  Movie  Shrek Forever After  Mike Mitchell
#
#                     country date_added  release_year  rating     genres  \
# 0  United States of America 2010-05-16          1970    6.38     Comedy
# 1  United States of America 2010-05-16          1970    6.38  Adventure
# 2  United States of America 2010-05-16          1970    6.38    Fantasy
# 3  United States of America 2010-05-16          1970    6.38  Animation
# 4  United States of America 2010-05-16          1970    6.38     Family
#
#    popularity  vote_count vote_average
# 0     203.893        7449      average
# 1     203.893        7449      average
# 2     203.893        7449      average
# 3     203.893        7449      average
# ...

# %%
df['country'] = df['country'].str.split(', ')
df = df.explode('country').reset_index(drop = True)
df.head()
# Out:
#    show_id   type                title       director  \
# 0    10192  Movie  Shrek Forever After  Mike Mitchell
# 1    10192  Movie  Shrek Forever After  Mike Mitchell
# 2    10192  Movie  Shrek Forever After  Mike Mitchell
# 3    10192  Movie  Shrek Forever After  Mike Mitchell
# 4    10192  Movie  Shrek Forever After  Mike Mitchell
#
#                     country date_added  release_year  rating     genres  \
# 0  United States of America 2010-05-16          1970    6.38     Comedy
# 1  United States of America 2010-05-16          1970    6.38  Adventure
# 2  United States of America 2010-05-16          1970    6.38    Fantasy
# 3  United States of America 2010-05-16          1970    6.38  Animation
# 4  United States of America 2010-05-16          1970    6.38     Family
#
#    popularity  vote_count vote_average
# 0     203.893        7449      average
# 1     203.893        7449      average
# 2     203.893        7449      average
# 3     203.893        7449      average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53080 entries, 0 to 53079
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       53080 non-null  int64
#  1   type          53080 non-null  object
#  2   title         53080 non-null  object
#  3   director      53080 non-null  object
#  4   country       53080 non-null  object
#  5   date_added    53080 non-null  object
#  6   release_year  53080 non-null  int64
#  7   rating        53080 non-null  float64
#  8   genres        53080 non-null  object
#  9   popularity    53080 non-null  float64
#  10  vote_count    53080 non-null  int64
#  11  vote_average  53080 non-null  float64
#  12  budget        53080 non-null  int64
#  13  revenue       53080 non-null  int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 5.7+ MB

# %% [markdown]
# Casting column into category

# %%
df['genres'] = df['genres'].astype('category')
df['genres'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
df.nunique()
# Out:
# show_id         15101
# type                1
# title           14616
# director         8893
# country           132
# date_added       4309
# release_year        1
# rating           2144
# genres             19
# popularity      10806
# vote_count       2692
# vote_average        4
# dtype: int64

# %% [markdown]
# ### DATA VISULATION

# %%
import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# ### What are the most common genres on Netflix?

# %%
df['genres'].describe()
# Out:
# count     51175
# unique       19
# top       Drama
# freq       9869
# Name: genres, dtype: object

# %%
sns.catplot(y = 'genres' , data= df, kind = 'count' , order = df['genres'].value_counts().index, color = '#4287f5')
plt.title('genres column distribution')
plt.show()

# %% [markdown]
# ### Which genres have the highest average ratings?

# %%
genre_avg_rating = df.groupby('genres')['rating'].mean().sort_values(ascending=False).reset_index()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11988\2234761161.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   genre_avg_rating = df.groupby('genres')['rating'].mean().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=genre_avg_rating, x='rating', y='genres', color = "green")
plt.title('Average Ratings by Genres')
plt.xlabel('Average Ratings')
plt.ylabel('Genres')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What movie got the highest popularity ? What are their genres?

# %%
df[df['popularity'] == df['popularity'].max()]
# Out:
#        show_id   type      title          director                   country  \
# 50412   950396  Movie  The Gorge  Scott Derrickson  United States of America
# 50413   950396  Movie  The Gorge  Scott Derrickson  United States of America
# 50414   950396  Movie  The Gorge  Scott Derrickson  United States of America
#
#        date_added  release_year  rating           genres  popularity  \
# 50412        2025          1970   7.785          Romance    3876.006
# 50413        2025          1970   7.785  Science Fiction    3876.006
# 50414        2025          1970   7.785         Thriller    3876.006
#
#        vote_count vote_average
# 50412        1572      popular
# 50413        1572      popular
# 50414        1572      popular

# %% [markdown]
# ### What movie got the lowest popularity ? What are their genres?

# %%
df[df['popularity'] == df['popularity'].min()]
# Out:
#       show_id   type                   title      director  \
# 3344    58884  Movie  Sympathy for Delicious  Mark Ruffalo
#
#                        country  date_added  release_year  rating genres  \
# 3344  United States of America        2010          1970   5.838  Drama
#
#       popularity  vote_count vote_average
# 3344        3.86          34    below_avg

# %% [markdown]
# ### Which year has the most filmmed movies

# %%
df['date_added'].hist()
plt.title("movie release year on Netflix")
plt.show()

# %% [markdown]
# ### What genres has the highest vote?

# %%
sns.catplot(y = 'vote_average' , data= df, kind = 'count' , order = df['vote_average'].value_counts().index, color = 'magenta')
plt.title('vote distribution')
plt.show()

# %%
Conclusion: 
 Q1: What are the most common genres on Netflix?
Drama genre is the most frequent genre in our dataset and has appeared more than 14% of the time amon 19 other geners.

Q2: Which genres have the highest average ratings?
Documentry genre has the highest rating which is more than 7 and all other have less than 6 .

Q3: What movie got the highest popularity ? What are their genres?
The Gorge has the highest popularity rate in our dataset and it has genres of Romance ,Science Fiction and Thriller.
    
Q4: What movie got the lowest popularity ? What are their genres?
Sympathy for Delicious has the lowest popularity rate in our dataset and it has genres of Drama.

Q5: Which year has the most filmmed movies?
year 2017 has the highest filmming rate in our dataset.

Q6: What genres has the highest vote?
we have 25.5% of our dataset with popular vote(13962 rows).Romance,Science Fiction and Thriller is the highest popularity accourding to our datasets.
